# %%
import pandas as pd
import numpy as np
# Out:
# C:\Users\NEO16\AppData\Local\Temp\ipykernel_56972\2162656668.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
data = pd.read_csv("Absenteeism_data.csv")
data.head()
# Out:
#    ID  Reason for Absence        Date  Transportation Expense  \
# 0  11                  26  07/07/2015                     289
# 1  36                   0  14/07/2015                     118
# 2   3                  23  15/07/2015                     179
# 3   7                   7  16/07/2015                     279
# 4  11                  23  23/07/2015                     289
#
#    Distance to Work  Age  Daily Work Load Average  Body Mass Index  Education  \
# 0                36   33                  239.554               30          1
# 1                13   50                  239.554               31          1
# 2                51   38                  239.554               31          1
# 3                 5   39                  239.554               24          1
# 4                36   33                  239.554               30          1
#
#    Children  Pets  Absenteeism Time in Hours
# 0         2     1                          4
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   ID                         700 non-null    int64
#  1   Reason for Absence         700 non-null    int64
#  2   Date                       700 non-null    object
#  3   Transportation Expense     700 non-null    int64
#  4   Distance to Work           700 non-null    int64
#  5   Age                        700 non-null    int64
#  6   Daily Work Load Average    700 non-null    float64
#  7   Body Mass Index            700 non-null    int64
#  8   Education                  700 non-null    int64
#  9   Children                   700 non-null    int64
#  10  Pets                       700 non-null    int64
#  11  Absenteeism Time in Hours  700 non-null    int64
# dtypes: float64(1), int64(10), object(1)
# memory usage: 65.8+ KB

# %%
data.describe()
# Out:
#                ID  Reason for Absence  Transportation Expense  \
# count  700.000000          700.000000              700.000000
# mean    17.951429           19.411429              222.347143
# std     11.028144            8.356292               66.312960
# min      1.000000            0.000000              118.000000
# 25%      9.000000           13.000000              179.000000
# 50%     18.000000           23.000000              225.000000
# 75%     28.000000           27.000000              260.000000
# max     36.000000           28.000000              388.000000
#
#        Distance to Work         Age  Daily Work Load Average  Body Mass Index  \
# count        700.000000  700.000000               700.000000       700.000000
# mean          29.892857   36.417143               271.801774        26.737143
# std           14.804446    6.379083                40.021804         4.254701
# min            5.000000   27.000000               205.917000        19.000000
# ...

# %%
def check(data):
    list=[]
    for col in data.columns:
        columns = data.columns
        dtype = data[col].dtypes
        instances = data[col].count()
        unique = data[col].nunique()
        sum_null = data[col].isnull().sum()
        duplicates = data.duplicated().sum()
        list.append([dtype,instances,unique,sum_null,duplicates])
    data_check = pd.DataFrame(list,columns=["dtype","instances","unique","sum_null","duplicates"],index=data.columns)
    return data_check

check(data)
# Out:
#                              dtype  instances  unique  sum_null  duplicates
# ID                           int64        700      34         0           8
# Reason for Absence           int64        700      28         0           8
# Date                        object        700     432         0           8
# Transportation Expense       int64        700      24         0           8
# Distance to Work             int64        700      24         0           8
# Age                          int64        700      21         0           8
# Daily Work Load Average    float64        700      35         0           8
# Body Mass Index              int64        700      16         0           8
# Education                    int64        700       4         0           8
# Children                     int64        700       5         0           8
# Pets                         int64        700       6         0           8
# ...

# %%
import pandas as pd 
pd.set_option('max_colwidth', 800)

# %%
def check_unique(data):
    nunique=data.apply(lambda col: col.nunique())
    unique_values = data.apply(lambda col: col.unique())
    data_check = pd.DataFrame({'uni_count': nunique, 'unique_values': unique_values})
    return data_check

check_unique(data)
# Out:
#                            uni_count  \
# ID                                34
# Reason for Absence                28
# Date                             432
# Transportation Expense            24
# Distance to Work                  24
# Age                               21
# Daily Work Load Average           35
# Body Mass Index                   16
# Education                          4
# Children                           5
# Pets                               6
# Absenteeism Time in Hours         19
#
# ...

# %%
#DROP THE ID COLUMN
data = data.drop("ID",axis=1)

# %%
data.head()
# Out:
#    Reason for Absence        Date  Transportation Expense  Distance to Work  \
# 0                  26  07/07/2015                     289                36
# 1                   0  14/07/2015                     118                13
# 2                  23  15/07/2015                     179                51
# 3                   7  16/07/2015                     279                 5
# 4                  23  23/07/2015                     289                36
#
#    Age  Daily Work Load Average  Body Mass Index  Education  Children  Pets  \
# 0   33                  239.554               30          1         2     1
# 1   50                  239.554               31          1         1     0
# 2   38                  239.554               31          1         0     0
# 3   39                  239.554               24          1         2     0
# 4   33                  239.554               30          1         2     1
#
#    Absenteeism Time in Hours
# ...

# %%
data[data["Reason for Absence"]==0].count()
# Out:
# Reason for Absence           38
# Date                         38
# Transportation Expense       38
# Distance to Work             38
# Age                          38
# Daily Work Load Average      38
# Body Mass Index              38
# Education                    38
# Children                     38
# Pets                         38
# Absenteeism Time in Hours    38
# dtype: int64

# %%
pd.options.display.max_columns = None

# %%
data.columns
# Out:
# Index(['Reason for Absence', 'Date', 'Transportation Expense',
#        'Distance to Work', 'Age', 'Daily Work Load Average', 'Body Mass Index',
#        'Education', 'Children', 'Pets', 'Absenteeism Time in Hours'],
#       dtype='object')

# %%
reason_dummy = pd.get_dummies(data=data["Reason for Absence"],prefix="RfA",drop_first=True,dtype=int)
group1 = reason_dummy.loc[:, 'RfA_1':'RfA_14'].max(axis=1)
group2 = reason_dummy.loc[:, 'RfA_15':'RfA_17'].max(axis=1)
group3 = reason_dummy.loc[:, 'RfA_18':'RfA_21'].max(axis=1)
group4 = reason_dummy.loc[:, 'RfA_22':'RfA_28'].max(axis=1)
new_df = pd.concat([data,group1,group2,group3,group4],axis=1).drop("Reason for Absence",axis=1)
new_df
# Out:
#            Date  Transportation Expense  Distance to Work  Age  \
# 0    07/07/2015                     289                36   33
# 1    14/07/2015                     118                13   50
# 2    15/07/2015                     179                51   38
# 3    16/07/2015                     279                 5   39
# 4    23/07/2015                     289                36   33
# ..          ...                     ...               ...  ...
# 695  23/05/2018                     179                22   40
# 696  23/05/2018                     225                26   28
# 697  24/05/2018                     330                16   28
# 698  24/05/2018                     235                16   32
# 699  31/05/2018                     291                31   40
#
#      Daily Work Load Average  Body Mass Index  Education  Children  Pets  \
# 0                    239.554               30          1         2     1
# ...

# %%
column_names = ['Date', 'Transportation Expense',
       'Distance to Work', 'Age', 'Daily Work Load Average', 'Body Mass Index',
       'Education', 'Children', 'Pets', 'Absenteeism Time in Hours', 'Reason1', 'Reason2', 'Reason3', 'Reason4']

# %%
new_df.columns = column_names

# %%
new_df.head()
# Out:
#          Date  Transportation Expense  Distance to Work  Age  \
# 0  07/07/2015                     289                36   33
# 1  14/07/2015                     118                13   50
# 2  15/07/2015                     179                51   38
# 3  16/07/2015                     279                 5   39
# 4  23/07/2015                     289                36   33
#
#    Daily Work Load Average  Body Mass Index  Education  Children  Pets  \
# 0                  239.554               30          1         2     1
# 1                  239.554               31          1         1     0
# 2                  239.554               31          1         0     0
# 3                  239.554               24          1         2     0
# 4                  239.554               30          1         2     1
#
#    Absenteeism Time in Hours  Reason1  Reason2  Reason3  Reason4
# 0                          4        0        0        0        1
# ...

# %%
new_df["Date"]=pd.to_datetime(new_df["Date"],format="%d/%m/%Y")

# %%
new_df["Month"]= new_df.Date.dt.month
new_df["Day of Week"]= new_df.Date.dt.weekday
new_df.drop(["Date"],axis=1,inplace=True)

# %%
reordered_columns = [ 'Reason1', 'Reason2', 'Reason3',
       'Reason4','Month','Day of Week','Transportation Expense', 'Distance to Work', 'Age',
       'Daily Work Load Average', 'Body Mass Index', 'Education', 'Children',
       'Pets', 'Absenteeism Time in Hours']
new_df = new_df[reordered_columns]

# %%
new_df.head()
# Out:
#    Reason1  Reason2  Reason3  Reason4  Month  Day of Week  \
# 0        0        0        0        1      7            1
# 1        0        0        0        0      7            1
# 2        0        0        0        1      7            2
# 3        1        0        0        0      7            3
# 4        0        0        0        1      7            3
#
#    Transportation Expense  Distance to Work  Age  Daily Work Load Average  \
# 0                     289                36   33                  239.554
# 1                     118                13   50                  239.554
# 2                     179                51   38                  239.554
# 3                     279                 5   39                  239.554
# 4                     289                36   33                  239.554
#
#    Body Mass Index  Education  Children  Pets  Absenteeism Time in Hours
# 0               30          1         2     1                          4
# ...

# %%
new_df.Education.unique()
# Out:
# array([1, 3, 2, 4], dtype=int64)

# %%
new_df["Education"]=new_df["Education"].map({1:0}).fillna(1)
new_df.head(10)
# Out:
#    Reason1  Reason2  Reason3  Reason4  Month  Day of Week  \
# 0        0        0        0        1      7            1
# 1        0        0        0        0      7            1
# 2        0        0        0        1      7            2
# 3        1        0        0        0      7            3
# 4        0        0        0        1      7            3
# 5        0        0        0        1      7            4
# 6        0        0        0        1      7            4
# 7        0        0        0        1      7            4
# 8        0        0        1        0      7            0
# 9        0        0        0        1      7            0
#
#    Transportation Expense  Distance to Work  Age  Daily Work Load Average  \
# 0                     289                36   33                  239.554
# 1                     118                13   50                  239.554
# 2                     179                51   38                  239.554
# ...

# %%
new_df["Education"]=new_df["Education"].apply(lambda i: int(i))
#new_df["Education"] = new_df["Education"].astype(int)

# %%
new_df.head(10)
# Out:
#    Reason1  Reason2  Reason3  Reason4  Month  Day of Week  \
# 0        0        0        0        1      7            1
# 1        0        0        0        0      7            1
# 2        0        0        0        1      7            2
# 3        1        0        0        0      7            3
# 4        0        0        0        1      7            3
# 5        0        0        0        1      7            4
# 6        0        0        0        1      7            4
# 7        0        0        0        1      7            4
# 8        0        0        1        0      7            0
# 9        0        0        0        1      7            0
#
#    Transportation Expense  Distance to Work  Age  Daily Work Load Average  \
# 0                     289                36   33                  239.554
# 1                     118                13   50                  239.554
# 2                     179                51   38                  239.554
# ...

# %%
new_df.to_csv("df_preprocessed1.csv")

# %% [markdown]
# ## <strong>II. Applying Module</strong>

# %%
from absenteeism_module import *

# %%
pd.read_csv("Absenteeism_new_data.csv")
# Out:
#     ID  Reason for Absence        Date  Transportation Expense  \
# 0   22                  27  01/06/2018                     179
# 1   10                   7  04/06/2018                     361
# 2   14                  23  06/06/2018                     155
# 3   17                  25  08/06/2018                     179
# 4   14                  10  08/06/2018                     155
# 5   28                  11  11/06/2018                     225
# 6   16                   7  13/06/2018                     118
# 7   22                  27  13/06/2018                     179
# 8   34                  26  15/06/2018                     118
# 9   34                  10  20/06/2018                     118
# 10  23                  22  21/06/2018                     378
# 11  36                  19  21/06/2018                     118
# 12  12                  19  22/06/2018                     233
# 13  22                  27  22/06/2018                     179
# ...

# %%
model = absenteeism_model('model', 'scaler')

# %%
model.load_and_clean_data("Absenteeism_new_data.csv")

# %%
model.predicted_outputs()

# %%
model.predicted_outputs().to_csv("Absenteeism_predictions.csv")

# %%
df_new_obs = pd.read_csv("Absenteeism_predictions.csv")

# %%
import pymysql

# %%
conn = pymysql.connect(database = 'predicted_outputs', user='root', password ='password')

# %%
cursor = conn.cursor()

# %%
df_new_obs.head(10)
# Out:
#    reason_1  reason_2  reason_3  reason_4  month_value  \
# 0         0         0         0         1            6
# 1         1         0         0         0            6
# 2         0         0         0         1            6
# 3         0         0         0         1            6
# 4         1         0         0         0            6
# 5         1         0         0         0            6
# 6         1         0         0         0            6
# 7         0         0         0         1            6
# 8         0         0         0         1            6
# 9         1         0         0         0            6
#
#    transportation_expense  age  body_mass_index  education  children  pets  \
# 0                     179   30               19          1         0     0
# 1                     361   28               27          0         1     4
# 2                     155   34               25          0         2     0
# ...

# %%
cursor.execute('SELECT * FROM predicted_outputs;')
# Out:
# 0

# %% [markdown]
# ## Creating the INSERT Statement

# %%
insert_query = 'INSERT INTO predicted_outputs VALUES'

# %%
insert_query
# Out:
# 'INSERT INTO predicted_outputs VALUES'

# %%
for i in range(df_new_obs.shape[0]):
    insert_query += "("
    for j in range(df_new_obs.shape[1]):
        insert_query += str(df_new_obs[df_new_obs.columns[j]][i]) + ","
    insert_query = insert_query[:-1] + "),"

# %%
insert_query
# Out:
# 'INSERT INTO predicted_outputs VALUES(0,0,0,1,6,179,30,19,1,0,0,0.105075,0),(1,0,0,0,6,361,28,27,0,1,4,0.81012,1),(0,0,0,1,6,155,34,25,0,2,0,0.24117,0),(0,0,0,1,6,179,40,22,1,2,0,0.160729,0),(1,0,0,0,6,155,34,25,0,2,0,0.751491,1),(1,0,0,0,6,225,28,24,0,1,2,0.692978,1),(1,0,0,0,6,118,46,25,0,2,0,0.63296,1),(0,0,0,1,6,179,30,19,1,0,0,0.105075,0),(0,0,0,1,6,118,37,28,0,0,0,0.133915,0),(1,0,0,0,6,118,37,28,0,0,0,0.595337,1),(0,0,0,1,6,378,36,21,0,2,4,0.286105,0),(0,0,1,0,6,118,50,31,0,1,0,0.756993,1),(0,0,1,0,6,233,31,21,1,1,8,0.221894,0),(0,0,0,1,6,179,30,19,1,0,0,0.105075,0),(0,0,0,0,6,235,48,33,0,1,5,0.0665591,0),(0,0,0,0,6,268,33,25,1,0,0,0.188043,0),(0,0,1,0,6,118,50,31,0,1,0,0.756993,1),(1,0,0,0,6,179,30,19,1,0,0,0.527669,1),(0,0,0,1,6,291,40,25,0,1,1,0.326469,0),(1,0,0,0,7,179,30,19,1,0,0,0.543492,1),(0,0,0,1,7,118,37,28,0,0,0,0.141467,0),(0,0,0,1,7,233,31,21,1,1,8,0.017512,0),(1,0,0,0,7,118,37,28,0,0,0,0.610567,1),(1,0,0,0,7,118,37,28,0,0,0,0.610567,1),(0,0,0,1,7,233,31,21,1,1,8,
# ...

# %%
insert_query = insert_query[:-1] + ";"
insert_query
# Out:
# 'INSERT INTO predicted_outputs VALUES(0,0,0,1,6,179,30,19,1,0,0,0.105075,0),(1,0,0,0,6,361,28,27,0,1,4,0.81012,1),(0,0,0,1,6,155,34,25,0,2,0,0.24117,0),(0,0,0,1,6,179,40,22,1,2,0,0.160729,0),(1,0,0,0,6,155,34,25,0,2,0,0.751491,1),(1,0,0,0,6,225,28,24,0,1,2,0.692978,1),(1,0,0,0,6,118,46,25,0,2,0,0.63296,1),(0,0,0,1,6,179,30,19,1,0,0,0.105075,0),(0,0,0,1,6,118,37,28,0,0,0,0.133915,0),(1,0,0,0,6,118,37,28,0,0,0,0.595337,1),(0,0,0,1,6,378,36,21,0,2,4,0.286105,0),(0,0,1,0,6,118,50,31,0,1,0,0.756993,1),(0,0,1,0,6,233,31,21,1,1,8,0.221894,0),(0,0,0,1,6,179,30,19,1,0,0,0.105075,0),(0,0,0,0,6,235,48,33,0,1,5,0.0665591,0),(0,0,0,0,6,268,33,25,1,0,0,0.188043,0),(0,0,1,0,6,118,50,31,0,1,0,0.756993,1),(1,0,0,0,6,179,30,19,1,0,0,0.527669,1),(0,0,0,1,6,291,40,25,0,1,1,0.326469,0),(1,0,0,0,7,179,30,19,1,0,0,0.543492,1),(0,0,0,1,7,118,37,28,0,0,0,0.141467,0),(0,0,0,1,7,233,31,21,1,1,8,0.017512,0),(1,0,0,0,7,118,37,28,0,0,0,0.610567,1),(1,0,0,0,7,118,37,28,0,0,0,0.610567,1),(0,0,0,1,7,233,31,21,1,1,8,
# ...
